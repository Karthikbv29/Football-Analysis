# %%
pip install mplsoccer
# Out:
# Collecting mplsoccer
#   Downloading mplsoccer-1.1.12-py3-none-any.whl (68 kB)
#      ---------------------------------------- 68.1/68.1 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\karth\anaconda3\lib\site-packages (from mplsoccer) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\karth\anaconda3\lib\site-packages (from mplsoccer) (3.7.0)
# Requirement already satisfied: pandas in c:\users\karth\anaconda3\lib\site-packages (from mplsoccer) (1.5.3)
# Requirement already satisfied: scipy in c:\users\karth\anaconda3\lib\site-packages (from mplsoccer) (1.10.0)
# Requirement already satisfied: requests in c:\users\karth\anaconda3\lib\site-packages (from mplsoccer) (2.28.1)
# Requirement already satisfied: pillow in c:\users\karth\anaconda3\lib\site-packages (from mplsoccer) (9.4.0)
# Requirement already satisfied: seaborn in c:\users\karth\anaconda3\lib\site-packages (from mplsoccer) (0.12.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\karth\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karth\anaconda3\lib\site-packages (from pandas->mplsoccer) (2022.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\karth\anaconda3\lib\site-packages (from requests->mplsoccer) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karth\anaconda3\lib\site-packages (from requests->mplsoccer) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karth\anaconda3\lib\site-packages (from requests->mplsoccer) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\karth\anaconda3\lib\site-packages (from requests->mplsoccer) (2.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\karth\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplsoccer) (1.16.0)
# Installing collected packages: mplsoccer
# Successfully installed mplsoccer-1.1.12
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)

# %%
pip install statsbombpy
# Out:
# Collecting statsbombpy
#   Downloading statsbombpy-1.10.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: pandas in c:\users\karth\anaconda3\lib\site-packages (from statsbombpy) (1.5.3)
# Collecting requests-cache
#   Downloading requests_cache-1.0.1-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.7/58.7 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\karth\anaconda3\lib\site-packages (from statsbombpy) (2.28.1)
# Requirement already satisfied: joblib in c:\users\karth\anaconda3\lib\site-packages (from statsbombpy) (1.1.1)
# Collecting inflect
#   Downloading inflect-6.0.4-py3-none-any.whl (34 kB)
# Collecting pydantic>=1.9.1
#   Downloading pydantic-1.10.7-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\karth\anaconda3\lib\site-packages (from pandas->statsbombpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karth\anaconda3\lib\site-packages (from pandas->statsbombpy) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\karth\anaconda3\lib\site-packages (from pandas->statsbombpy) (1.23.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\karth\anaconda3\lib\site-packages (from requests->statsbombpy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karth\anaconda3\lib\site-packages (from requests->statsbombpy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karth\anaconda3\lib\site-packages (from requests->statsbombpy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\karth\anaconda3\lib\site-packages (from requests->statsbombpy) (1.26.14)
# Requirement already satisfied: attrs>=21.2 in c:\users\karth\anaconda3\lib\site-packages (from requests-cache->statsbombpy) (22.1.0)
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting cattrs>=22.2
#   Downloading cattrs-22.2.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\karth\anaconda3\lib\site-packages (from requests-cache->statsbombpy) (2.5.2)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\karth\anaconda3\lib\site-packages (from pydantic>=1.9.1->inflect->statsbombpy) (4.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\karth\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->statsbombpy) (1.16.0)
# Installing collected packages: url-normalize, pydantic, exceptiongroup, inflect, cattrs, requests-cache, statsbombpy
# Successfully installed cattrs-22.2.0 exceptiongroup-1.1.1 inflect-6.0.4 pydantic-1.10.7 requests-cache-1.0.1 statsbombpy-1.10.0 url-normalize-1.4.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\users\karth\anaconda3\lib\site-packages)

# %%
from statsbombpy import sb

# %%
sb.competitions()
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         90                   England
# 16              37         42                   England
# 17              37          4                   England
# 18              43        106             International
# 19              43          3             International
# 20            1238        108                     India
# 21              11         90                     Spain
# 22              11         42                     Spain
# 23              11          4                     Spain
# 24              11          1                     Spain
# 25              11          2                     Spain
# 26              11         27                     Spain
# 27              11         26                     Spain
# 28              11         25                     Spain
# 29              11         24                     Spain
# 30              11         23                     Spain
# 31              11         22                     Spain
# 32              11         21                     Spain
# 33              11         41                     Spain
# 34              11         40                     Spain
# 35              11         39                     Spain
# 36              11         38                     Spain
# 37              11         37                     Spain
# 38              49          3  United States of America
# 39               2         44                   England
# 40              55         43                    Europe
# 41              53        106                    Europe
# 42              72         30             International
#
#            competition_name competition_gender  competition_youth  \
# 0          Champions League               male              False
# 1          Champions League               male              False
# 2          Champions League               male              False
# 22  2023-04-19T10:52:22.240135
# 23  2023-05-11T08:22:01.941875
# 24  2023-04-25T00:10:26.116531
# 25  2023-05-11T08:13:40.117646
# 26  2023-02-21T15:55:07.071365
# 27  2022-08-14T18:49:03.341489
# 28  2022-07-23T12:18:49.547396
# 29  2022-09-25T20:52:24.444609
# 30  2022-12-01T14:10:17.791769
# 31  2023-04-19T10:48:44.079830
# 32  2023-04-19T10:48:01.770383
# 33  2023-04-19T10:46:29.203565
# 34  2023-04-19T10:42:35.284291
# 35  2023-03-26T23:19:39.125951
# 36  2022-07-03T12:34:31.749038
# 37            2020-07-29T05:00
# 38  2023-04-19T10:28:36.824565
# 39  2023-03-11T10:52:12.579230
# 40  2023-02-24T21:26:47.128979
# 41  2023-02-22T23:06:39.942980
# 42  2023-04-07T09:00:52.515359

# %%
sb.matches(competition_id=16,season_id=22)
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    match_id  match_date      kick_off                competition     season  \
# 0     18236  2011-05-28  20:45:00.000  Europe - Champions League  2010/2011
#
#    home_team          away_team  home_score  away_score match_status  ...  \
# 0  Barcelona  Manchester United           3           1    available  ...
#
#           last_updated_360 match_week competition_stage          stadium  \
# 0  2021-06-13T16:17:31.694          1             Final  Wembley Stadium
#
#          referee           home_managers  away_managers data_version  \
# 0  Viktor Kassai  Josep Guardiola i Sala  Alex Ferguson        1.0.3
#
#   shot_fidelity_version xy_fidelity_version
# 0                  None                None
#
# [1 rows x 22 columns]

# %%
match=sb.events(match_id=18236)
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
match
# Out:
#      bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0                   NaN                  NaN                     NaN
# 1                   NaN                  NaN                     NaN
# 2                   NaN                  NaN                     NaN
# 3                   NaN                  NaN                     NaN
# 4                   NaN                  NaN                     NaN
# ...                 ...                  ...                     ...
# 4321                NaN                  NaN                     NaN
# 4322                NaN                  NaN                     NaN
# 4323                NaN                  NaN                     NaN
# 4324                NaN                  NaN                     NaN
# 4325        Yellow Card                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_save_block carry_end_location  \
# 0                               NaN              NaN                NaN
# 1                               NaN              NaN                NaN
# 2                               NaN              NaN                NaN
# 3                               NaN              NaN                NaN
# 4                               NaN              NaN                NaN
# ...                             ...              ...                ...
# 4321                            NaN              NaN                NaN
# 4322                            NaN              NaN                NaN
# 4323                            NaN              NaN                NaN
# 4324                            NaN              NaN                NaN
# 4325                            NaN              NaN                NaN
#
#      clearance_aerial_won counterpress dribble_outcome dribble_overrun  ...  \
# 0                     NaN          NaN             NaN             NaN  ...
# 1                     NaN          NaN             NaN             NaN  ...
# 2                     NaN          NaN             NaN             NaN  ...
# 3                     NaN          NaN             NaN             NaN  ...
# 4                     NaN          NaN             NaN             NaN  ...
# ...                   ...          ...             ...             ...  ...
# 4321                  NaN          NaN             NaN             NaN  ...
# 4322                  NaN          NaN             NaN             NaN  ...
# 4323                  NaN          NaN             NaN             NaN  ...
# 4324                  NaN          NaN             NaN             NaN  ...
# 4325                  NaN          NaN             NaN             NaN  ...
#
#      shot_technique shot_type  substitution_outcome  substitution_replacement  \
# 0               NaN       NaN                   NaN                       NaN
# 1               NaN       NaN                   NaN                       NaN
# 2               NaN       NaN                   NaN                       NaN
# 3               NaN       NaN                   NaN                       NaN
# 4               NaN       NaN                   NaN                       NaN
# ...             ...       ...                   ...                       ...
# 4321            NaN       NaN              Tactical              Paul Scholes
# 4322            NaN       NaN              Tactical              Seydou Kéita
# 4323            NaN       NaN              Tactical  Carles Puyol i Saforcada
# 4324            NaN       NaN              Tactical           Ibrahim Afellay
# 4325            NaN       NaN                   NaN                       NaN
#
#                                                 tactics               team  \
# 0     {'formation': 41221, 'lineup': [{'player': {'i...          Barcelona
# 1     {'formation': 4222, 'lineup': [{'player': {'id...  Manchester United
# 2                                                   NaN  Manchester United
# 3                                                   NaN          Barcelona
# 4                                                   NaN  Manchester United
# ...                                                 ...                ...
# 4321                                                NaN  Manchester United
# 4322                                                NaN          Barcelona
# 4323                                                NaN          Barcelona
# 4324                                                NaN          Barcelona
# 4325                                                NaN          Barcelona
#
#      team_id     timestamp           type under_pressure
# 0        217  00:00:00.000    Starting XI            NaN
# 1         39  00:00:00.000    Starting XI            NaN
# 2         39  00:00:00.000     Half Start            NaN
# 3        217  00:00:00.000     Half Start            NaN
# 4         39  00:00:00.000     Half Start            NaN
# ...      ...           ...            ...            ...
# 4321      39  00:31:19.014   Substitution            NaN
# 4322     217  00:40:12.316   Substitution            NaN
# 4323     217  00:42:47.859   Substitution            NaN
# 4324     217  00:46:25.794   Substitution            NaN
# 4325     217  00:39:56.275  Bad Behaviour            NaN
#
# [4326 rows x 73 columns]

# %%
match.columns
# Out:
# Index(['bad_behaviour_card', 'ball_receipt_outcome', 'ball_recovery_offensive',
#        'ball_recovery_recovery_failure', 'block_save_block',
#        'carry_end_location', 'clearance_aerial_won', 'counterpress',
#        'dribble_outcome', 'dribble_overrun', 'duel_outcome', 'duel_type',
#        'duration', 'foul_committed_advantage', 'foul_committed_card',
#        'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive',
#        'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome',
#        'goalkeeper_position', 'goalkeeper_technique', 'goalkeeper_type', 'id',
#        'index', 'interception_outcome', 'location', 'match_id', 'minute',
#        'off_camera', 'pass_aerial_won', 'pass_angle', 'pass_assisted_shot_id',
#        'pass_backheel', 'pass_body_part', 'pass_cross', 'pass_end_location',
#        'pass_goal_assist', 'pass_height', 'pass_length', 'pass_outcome',
#        'pass_recipient', 'pass_shot_assist', 'pass_switch', 'pass_type',
#        'period', 'play_pattern', 'player', 'player_id', 'position',
#        'possession', 'possession_team', 'possession_team_id', 'related_events',
#        'second', 'shot_body_part', 'shot_end_location', 'shot_first_time',
#        'shot_freeze_frame', 'shot_key_pass_id', 'shot_outcome',
#        'shot_statsbomb_xg', 'shot_technique', 'shot_type',
#        'substitution_outcome', 'substitution_replacement', 'tactics', 'team',
#        'team_id', 'timestamp', 'type', 'under_pressure'],
#       dtype='object')

# %%
match['type'].value_counts()
# Out:
# Pass                 1222
# Ball Receipt*        1168
# Carry                1085
# Pressure              389
# Ball Recovery          83
# Duel                   55
# Dribble                44
# Dribbled Past          34
# Goal Keeper            29
# Interception           28
# Shot                   26
# Block                  26
# Dispossessed           25
# Miscontrol             23
# Foul Won               22
# Foul Committed         22
# Clearance              17
# Tactical Shift          6
# Substitution            5
# Half Start              4
# Half End                4
# Shield                  3
# Starting XI             2
# Referee Ball-Drop       2
# Offside                 1
# Bad Behaviour           1
# Name: type, dtype: int64

# %%
from mplsoccer import Pitch
pitch=Pitch(pitch_type='statsbomb')
pitch.draw()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %% [markdown]
# # Shot Map

# %%
from mplsoccer import VerticalPitch
pitch_shot=VerticalPitch(pitch_type='statsbomb',half=True)
pitch_shot.draw()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
#Retrieve rows that record shots
shots = match[match.type=='Shot']

# Filtering data that record Barca
shots_barca=shots[shots.team == 'Barcelona']

# Column Selection
shots_barca=shots_barca[['team','player','minute','second','location','shot_statsbomb_xg','shot_end_location','shot_outcome']]

#
shots_barca['x']=shots_barca.location.apply(lambda x:x[0])
shots_barca['y']=shots_barca.location.apply(lambda x:x[1])

shots_barca['endx']=shots_barca.shot_end_location.apply(lambda x:x[0])
shots_barca['endy']=shots_barca.shot_end_location.apply(lambda x:x[1])

# %%
goals_barca=shots_barca[shots_barca.shot_outcome=='Goal']
shots_barca=shots_barca[shots_barca.shot_outcome!='Goal']

# %%
#Retrieve rows that record shots
shots = match[match.type=='Shot']

# Filtering data that record Manchester United
shots_mu=shots[shots.team == 'Manchester United']

# Column Selection
shots_mu=shots_mu[['team','player','minute','second','location','shot_statsbomb_xg','shot_end_location','shot_outcome']]

#
shots_mu['x']=shots_mu.location.apply(lambda x:x[0])
shots_mu['y']=shots_mu.location.apply(lambda x:x[1])

shots_mu['endx']=shots_mu.shot_end_location.apply(lambda x:x[0])
shots_mu['endy']=shots_mu.shot_end_location.apply(lambda x:x[1])

# %%
goals_mu=shots_mu[shots_mu.shot_outcome=='Goal']
shots_mu=shots_mu[shots_mu.shot_outcome!='Goal']

# %%
goals_mu
# Out:
#                    team             player  minute  second       location  \
# 4179  Manchester United  Wayne Mark Rooney      33       5  [105.0, 43.0]
#
#       shot_statsbomb_xg   shot_end_location shot_outcome      x     y   endx  \
# 4179           0.153701  [120.0, 37.6, 1.9]         Goal  105.0  43.0  120.0
#
#       endy
# 4179  37.6

# %%
def goal_map(shots_df,goals_df):
    from mplsoccer import VerticalPitch
    import matplotlib.pyplot as plt

    pitch = VerticalPitch(pitch_type='statsbomb',half=True, goal_type='box',
                     goal_alpha=0.8,pitch_color='#22312b',line_color='#c7d5cc')

    fig, axs = pitch.grid(figheight=10, title_height=0.08, endnote_space=0, axis=False,
                      title_space=0, grid_height=0.82, endnote_height=0.05)

    fig.set_facecolor("#22312b")

    scatter_shots = pitch.scatter(shots_df.x, shots_df.y, s=(shots_df.shot_statsbomb_xg * 900)+100,
                              c='red', edgecolors='black', marker='o', ax=axs['pitch'])

    scatter_goals = pitch.scatter(goals_df.x, goals_df.y, s=(goals_df.shot_statsbomb_xg * 900)+100, 
                               edgecolors='black', marker='football', ax=axs['pitch'])

    lines_goals = pitch.lines(goals_df.x, goals_df.y, goals_df.endx, goals_df.endy, color='red',ax=axs['pitch'])

    pitch.arrows(70,5,100,5,ax=axs['pitch'],color='#c7d5cc')

    axs['endnote'].text(0.85, 0.5, '[Karthik Bhagavatula]', color='#c7d5cc', va='center', ha='center', fontsize=15)
    axs['title'].text(0.5, 0.7, 'The Shot Map of FC Barcelona', color='#c7d5cc', va='center', ha='center', fontsize=30)
    axs['title'].text(0.5, 0.25, 'Whole Game', color='#c7d5cc', va='center', ha='center', fontsize=18)

    return plt.show()

# %%
goal_map(shots_mu,goals_mu)

# %%
match.type.value_counts()
# Out:
# Pass                 1222
# Ball Receipt*        1168
# Carry                1085
# Pressure              389
# Ball Recovery          83
# Duel                   55
# Dribble                44
# Dribbled Past          34
# Goal Keeper            29
# Interception           28
# Shot                   26
# Block                  26
# Dispossessed           25
# Miscontrol             23
# Foul Won               22
# Foul Committed         22
# Clearance              17
# Tactical Shift          6
# Substitution            5
# Half Start              4
# Half End                4
# Shield                  3
# Starting XI             2
# Referee Ball-Drop       2
# Offside                 1
# Bad Behaviour           1
# Name: type, dtype: int64

# %% [markdown]
# # Pressure Map

# %%
pressure = match[match.type=='Pressure']
pressure = pressure[['team','player','location']]
pressure = pressure[pressure.team == 'Barcelona']

pressure['x'] = pressure.location.apply(lambda x:x[0])
pressure['y'] = pressure.location.apply(lambda x:x[1])

# %%
pressure
# Out:
#            team                           player       location      x     y
# 3481  Barcelona   Lionel Andrés Messi Cuccittini   [58.0, 43.0]   58.0  43.0
# 3484  Barcelona         Sergio Busquets i Burgos   [51.0, 68.0]   51.0  68.0
# 3485  Barcelona            Daniel Alves da Silva   [18.0, 70.0]   18.0  70.0
# 3486  Barcelona              David Villa Sánchez   [81.0, 72.0]   81.0  72.0
# 3487  Barcelona              David Villa Sánchez  [107.0, 56.0]  107.0  56.0
# ...         ...                              ...            ...    ...   ...
# 3861  Barcelona             Andrés Iniesta Luján   [98.0, 29.0]   98.0  29.0
# 3862  Barcelona  Pedro Eliezer Rodríguez Ledesma   [32.0, 64.0]   32.0  64.0
# 3863  Barcelona                  Ibrahim Afellay   [46.0, 74.0]   46.0  74.0
# 3865  Barcelona         Sergio Busquets i Burgos   [77.0, 63.0]   77.0  63.0
# 3869  Barcelona           Xavier Hernández Creus  [113.0, 76.0]  113.0  76.0
#
# [143 rows x 5 columns]

# %%
from scipy.ndimage import gaussian_filter

pitch2=Pitch(pitch_type='statsbomb',line_zorder =2,pitch_color='#22312b',line_color='#efefef')

fig2, axs2 = pitch2.grid(figheight=10, title_height=0.08, endnote_space=0, axis=False,
                      title_space=0, grid_height=0.82, endnote_height=0.05)

fig2.set_facecolor("#22312b")

bin_statistic = pitch2.bin_statistic(pressure.x, pressure.y, statistic='count', bins=(25, 25))

bin_statistic['statistic'] = gaussian_filter(bin_statistic['statistic'],1)

pcm = pitch2.heatmap(bin_statistic,ax=axs2['pitch'],cmap='hot',edgecolors='#22312b')

cbar = fig2.colorbar(pcm, ax = axs2['pitch'],shrink=0.6)

cbar.outline.set_edgecolor('#efefef')

cbar.ax.yaxis.set_tick_params(color='#efefef')

plt.setp(plt.getp(cbar.ax.axes,'yticklabels'),color = '#efefef')

axs2['endnote'].text(0.8,0.5,'Karthik Bhagavatula',color='#c7d5cc',va='center',ha='center',fontsize=10)

axs2['endnote'].text(0.4,0.95,'Attacking Direction',color='#c7d5cc',va='center',ha='center',fontsize=12)

axs2['endnote'].arrow(0.3,0.6,0.2,0, head_width = 0.2, head_length = 0.025, ec='w',fc='w')

axs2['endnote'].set_xlim(0,1)
axs2['endnote'].set_ylim(0,1)

axs2['title'].text(0.5,0.7,'FC Barcelona\'s Pressure Heat Map',color='#c7d5cc',va='center',ha='center',fontsize=30)

plt.show()

# %%
match['pass_outcome'].value_counts()
# Out:
# Incomplete          149
# Out                  21
# Unknown              12
# Pass Offside          6
# Injury Clearance      1
# Name: pass_outcome, dtype: int64

# %% [markdown]
# # Passing Map

# %%
passing = match[match.type=='Pass']
passing = passing[['team','player','pass_outcome','pass_goal_assist','location','pass_end_location']]
passing = passing[passing.team == 'Barcelona']

passing['x'] = passing.location.apply(lambda x:x[0])
passing['y'] = passing.location.apply(lambda x:x[1])
passing['endx'] = passing.pass_end_location.apply(lambda x:x[0])
passing['endy'] = passing.pass_end_location.apply(lambda x:x[1])

# %%
assists=passing[passing.pass_goal_assist==True]

# %%
assists
# Out:
#           team                    player pass_outcome pass_goal_assist  \
# 429  Barcelona    Xavier Hernández Creus     Complete             True
# 738  Barcelona      Andrés Iniesta Luján     Complete             True
# 915  Barcelona  Sergio Busquets i Burgos     Complete             True
#
#           location pass_end_location      x     y   endx  endy
# 429   [89.0, 34.0]     [104.0, 48.0]   89.0  34.0  104.0  48.0
# 738   [82.0, 27.0]      [82.0, 47.0]   82.0  27.0   82.0  47.0
# 915  [105.0, 55.0]      [98.0, 43.0]  105.0  55.0   98.0  43.0

# %%
xavi_passes_ucl2011 = passing[passing.player=='Xavier Hernández Creus']
xavi_passes_ucl2011.head()

iniesta_passes_ucl2011 = passing[passing.player=='Andrés Iniesta Luján']

busquets_passes_ucl2011 = passing[passing.player=='Sergio Busquets i Burgos']

messi_passes_ucl2011 = passing[passing.player=='Lionel Andrés Messi Cuccittini']

# %%
passing['pass_outcome']=passing['pass_outcome'].fillna('Complete')

# %%
# Setup the pitch
def players_passing(df):

    pitch3 = Pitch(pitch_type='statsbomb', pitch_color='#22312b',
               line_color='#c7d5cc')
    fig3,ax3 = plt.subplots(figsize=(20,18))
    fig3.set_facecolor('#22312b')
    ax3.patch.set_facecolor('#22312b')

    pitch3.draw(ax=ax3)

    if 'pass_outcome' in df.columns:
        for index, row in df.iterrows():
            if row['pass_outcome'] == 'Complete':
                plt.plot((row['x'], row['endx']), (row['y'], row['endy']), color='green')
                plt.scatter(row['x'],row['y'], color = 'green')
            if row['pass_outcome'] == 'Incomplete':
                plt.plot((row['x'], row['endx']), (row['y'], row['endy']), color='red')
                plt.scatter(row['x'],row['y'], color = 'red')    
    
    return plt.show()

# %%
players_passing(iniesta_passes_ucl2011)

# %%
players_passing(xavi_passes_ucl2011)

# %%
players_passing(busquets_passes_ucl2011)

# %%
players_passing(messi_passes_ucl2011)

# %%
players_passing(passing)

# %%
xavi_passes_ucl2011.to_csv('xavi_passes_ucl_2011.csv')

# %%
iniesta_passes_ucl2011.to_csv('iniesta_passes_ucl_2011.csv')

# %%
busquets_passes_ucl2011.to_csv('busi_passes_ucl_2011.csv')

# %%
messi_passes_ucl2011.to_csv('messi_passes_ucl_2011.csv')
